# %%
import pandas as pd
import numpy as np
import quandl
from fbprophet import Prophet
from tracktorScrape import main
#dates, prices = main("B06XCM9LJ4")
#a = []
#b = []
#for i in prices:
    #a.append(float(i[0]))
    #b.append(float(i[1]))

#print(a)
import pandas as pd






quandl.ApiConfig.api_key = "G9JAXw4pjPrWnEkxqRGo"
df = quandl.get('BCHARTS/BITSTAMPUSD', returns='pandas')
#df = pd.read_csv('~/Downloads/BTCDATA1.csv')
datelist = pd.date_range(pd.datetime.today(), periods=len(df)).tolist()
#print(len(a),len(datelist))
df =  pd.DataFrame(df)

print(df.columns)

df["ds"] = df.index
df["y"] = df["High"]
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)

'''
df2 = pd.DataFrame( {"ds":datelist }  )
#df = pd.read_csv("fbprophet/btc.csv")
print(df.columns)
df['Date'] = df.index
#df['y'] = np.log(df['High'])
df2['y'] = (df['High'])
for i in range(0,len(df2["y"])):
    if df2["y"][i] is not float:
        df2["y"][i] = df2["y"][i-1]

df["ds"] = df["Date"]

m = Prophet()
m.fit(df2);
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
'''
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Index(['Open', 'High', 'Low', 'Close', 'Volume (BTC)', 'Volume (Currency)',
#        'Weighted Price'],
#       dtype='object')
# /Users/vibhav/miniconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# '\ndf2 = pd.DataFrame( {"ds":datelist }  )\n#df = pd.read_csv("fbprophet/btc.csv")\nprint(df.columns)\ndf[\'Date\'] = df.index\n#df[\'y\'] = np.log(df[\'High\'])\ndf2[\'y\'] = (df[\'High\'])\nfor i in range(0,len(df2["y"])):\n    if df2["y"][i] is not float:\n        df2["y"][i] = df2["y"][i-1]\n\ndf["ds"] = df["Date"]\n\nm = Prophet()\nm.fit(df2);\nfuture = m.make_future_dataframe(periods=365)\nforecast = m.predict(future)\n'

# %%
m.plot(forecast)

# %%
#m.plot_components(forecast)
df.columns

# %%
class Graph_Mult():
    def __init__(self, W_regularizer=None, u_regularizer=None, b_regularizer=None,
                 W_constraint=None, u_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        pass

# %%
forecast.tail(300)
# Out:
#              ds         trend   trend_lower   trend_upper    yhat_lower  \
# 2508 2018-07-26  13647.089204  13602.415056  13685.996457  11817.989985
# 2509 2018-07-27  13671.484331  13625.406320  13711.641567  11877.944553
# 2510 2018-07-28  13695.879457  13648.208971  13737.870724  11881.129865
# 2511 2018-07-29  13720.274584  13671.016776  13763.766373  11937.339142
# 2512 2018-07-30  13744.669710  13693.653179  13789.579242  11979.324871
# 2513 2018-07-31  13769.064836  13716.418378  13815.351329  11976.291550
# 2514 2018-08-01  13793.459963  13739.318952  13840.760404  12008.869413
# 2515 2018-08-02  13817.855089  13762.171590  13865.685445  12086.862603
# 2516 2018-08-03  13842.250216  13785.121982  13891.036769  11935.377765
# 2517 2018-08-04  13866.645342  13807.980438  13916.858575  12014.624107
# 2518 2018-08-05  13891.040469  13830.938091  13942.125784  12051.530258
# 2519 2018-08-06  13915.435595  13853.685653  13969.073250  12201.766134
# ...

# %%
future
# Out:
#              ds
# 0    2011-09-13
# 1    2011-09-14
# 2    2011-09-15
# 3    2011-09-16
# 4    2011-09-17
# 5    2011-09-18
# 6    2011-09-19
# 7    2011-09-20
# 8    2011-09-21
# 9    2011-09-22
# 10   2011-09-23
# 11   2011-09-24
# 12   2011-09-25
# 13   2011-09-26
# 14   2011-09-27
# 15   2011-09-28
# 16   2011-09-29
# 17   2011-09-30
# 18   2011-10-01
# 19   2011-10-02
# 20   2011-10-03
# 21   2011-10-04
# 22   2011-10-05
# 23   2011-10-06
# 24   2011-10-07
# 25   2011-10-08
# 26   2011-10-09
# 27   2011-10-10
# 28   2011-10-11
# 29   2011-10-12
# ...         ...
# 2761 2019-04-05
# 2762 2019-04-06
# 2763 2019-04-07
# 2764 2019-04-08
# 2765 2019-04-09
# 2766 2019-04-10
# 2767 2019-04-11
# 2768 2019-04-12
# 2769 2019-04-13
# 2770 2019-04-14
# 2771 2019-04-15
# 2772 2019-04-16
# 2773 2019-04-17
# 2774 2019-04-18
# 2775 2019-04-19
# 2776 2019-04-20
# 2777 2019-04-21
# 2778 2019-04-22
# 2779 2019-04-23
# 2780 2019-04-24
# 2781 2019-04-25
# 2782 2019-04-26
# 2783 2019-04-27
# ...

# %%
dat = max(forecast[:10]["yhat"])
